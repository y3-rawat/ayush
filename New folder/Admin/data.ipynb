# %%
import pandas as pd

# %%
pd.read_json("Admin_database.json")
# Out:
#    total_users_visited Repetative_Users_id Most_car_viewed_user_id  \
# 0                  534        [1, 2, 4, 3]                     [4]
#
#    Dealers_on_webiste           Transections_history  Car_Sold_total  \
# 0                 432  {'approved': 3, 'pending': 1}            4321
#
#    Car_sold_last_month                                   top_5_cars_viewd  \
# 0                   54  [Ford Mustang, Chevrolet Camaro, BMW X5, Audi ...
#
#                             common_issues_on_webiste  \
# 0  [webiste has too much loading time, cars are e...
#
#                                    most_bids_of_cars
# 0  {'Jaguar': 53421, 'Lamborghini': 4532, 'Porsch...

# %%
pd.read_csv("data_car.csv").head()
# Out:
#    Unnamed: 0                        id                         name  \
# 0           0  65cdc4b6c80de2014a79b41c            Ferrari 488 Pista
# 1           1  65e583d6473b761be3fddd47                McLaren 720S
# 2           2  65e584fd473b761be3fddd48                MARK IV RED.
# 3           3  65e586ec473b761be3fddd49  2014 Lamborghini Aventador
# 4           4  65e587cd473b761be3fddd4a                  Ferrari 458
#
#                    slug   price  isFeatured heroimagealttag  \
# 0    ferrari-488-plista  100000        True             NaN
# 1         mc-laren-720s  100000        True             car
# 2           mark-iv-red   47200       False            Mark
# 3  lamborgini-aventador   35000        True      lamborgini
# 4           ferrari-458  255000       False         ferrari
#
#                                          description  year kilometers  \
# 0  It is a long established fact that a reader wi...  2010      24000
# ...
