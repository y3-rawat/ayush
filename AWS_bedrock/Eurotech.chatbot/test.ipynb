# %%
import conversation
a = conversation.userQuestion("hy there")

# %%
with open ("website_about.text") as f:
        key = f.read()
key
# Out:
# "About Eurotech Xchange\nExotic Auto is not your traditional car-selling site. Exotic Auto offers an easy and quick way to sell your exotic vehicle. Itâ€™s simple: submit your vehicleâ€™s information for an instant offer, drop off your vehicle or we will come to you, and get paid! Whether you have a payoff on your vehicle or you own the vehicle entirely, we will handle everything from payoffs to paperwork.\n\nWhy Choose Us\nEurotech Xchange offers a quick and easy process with no stress involved. Eurotech Xchange will facilitate your vehicle purchase to you, no matter where you are located, Eurotech Xchange is a targeting being a leader in the digital platform exotic vehicle industry, making this process as simple as possible. No time wasted. No hassle or stress involved.\n\nEurotech Xchange\nOur collections comprises of both used and new vehicles aimed to deliver within expectations. Our team intent is to provider the best options available for purchasing and receiving your order, a
# ...

# %%
import pandas as pd

# %%
pd.read_csv("data_car.csv")
# Out:
#     Unnamed: 0                        id  \
# 0            0  65cdc4b6c80de2014a79b41c
# 1            1  65e583d6473b761be3fddd47
# 2            2  65e584fd473b761be3fddd48
# 3            3  65e586ec473b761be3fddd49
# 4            4  65e587cd473b761be3fddd4a
# 5            5  65e58a3b473b761be3fddd4c
# 6            6  65e58b02473b761be3fddd4d
# 7            7  65e594ae473b761be3fddd54
# 8            8  65eadb13cb1bc03992debda5
# 9            9  65fac4779277ddc4592aac48
# 10          10  65fac5ad9277ddc4592aac49
# 11          11  65fac6f79277ddc4592aac4a
# 12          12  65fac7f39277ddc4592aac4b
# 13          13  65fac8df9277ddc4592aac4c
# 14          14  65fac9fa9277ddc4592aac4d
# 15          15  65facac89277ddc4592aac4e
# 16          16  65facb7e9277ddc4592aac4f
# 17          17  65facd309277ddc4592aac50
# 18          18  65face2a9277ddc4592aac51
# 19          19  65facef59277ddc4592aac52
# 20          20  65facfbd9277ddc4592aac53
# 21          21  65fad09d9277ddc4592aac54
# ...

# %%
from langchain_groq import ChatGroq

# %%
from langchain.chains import ConversationChain
from langchain_groq import ChatGroq

key = "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"
llm_groq = ChatGroq(
                groq_api_key=key, model_name="llama3-70b-8192",
                                temperature=0.2)


conversation = ConversationChain(llm=llm_groq)

# %%
b = conversation("hy")
b["response"]
# Out:
# "Hello there! It's great to chat with you! I've been trained on a massive dataset of text from the internet, which means I can provide information on a wide range of topics. Did you know that I've been trained on over 45GB of text data, which is equivalent to reading around 20 million pages of text? Anyway, how's your day going so far?"

# %%
conversation("my name is yash")
# Out:
# {'input': 'my name is yash',
#  'history': "Human: hy\nAI: Hello there! It's great to chat with you! I've been trained on a massive dataset of text from the internet and can provide information on a wide range of topics. I'm feeling particularly chatty today, so fire away with any questions you have! By the way, did you know that the shortest war in history was between Britain and Zanzibar on August 27, 1896, and lasted only 38 minutes?",
#  'response': "Nice to meet you, Yash! I'm thrilled to be chatting with you. I've been trained on a vast amount of text data, so I'm ready to dive into any topic that piques your interest. By the way, did you know that the longest word in the English language, according to the Oxford English Dictionary, is pneumonoultramicroscopicsilicovolcanoconiosis, a lung disease caused by inhaling very fine particles of silica? It has 45 letters! What's on your mind, Yash?"}

# %%
conversation("thanks")
# Out:
# {'input': 'thanks',
#  'history': "Human: hy\nAI: Hello there! It's great to chat with you! I've been trained on a massive dataset of text from the internet and can provide information on a wide range of topics. I'm feeling particularly chatty today, so fire away with any questions you have! By the way, did you know that the shortest war in history was between Britain and Zanzibar on August 27, 1896, and lasted only 38 minutes?\nHuman: my name is yash\nAI: Nice to meet you, Yash! I'm thrilled to be chatting with you. I've been trained on a vast amount of text data, so I'm ready to dive into any topic that piques your interest. By the way, did you know that the longest word in the English language, according to the Oxford English Dictionary, is pneumonoultramicroscopicsilicovolcanoconiosis, a lung disease caused by inhaling very fine particles of silica? It has 45 letters! What's on your mind, Yash?",
# ...

# %%
conversation("do you know my name")
# Out:
# {'input': 'do you know my name',
# ...

# %%
import conversation
a = conversation.userQuestion("hy")
# Out:
# {'result': {'data': {'json': [{'id': '65cdc4b6c80de2014a79b41c', 'name': 'Ferrari 488 Pista', 'slug': 'ferrari-488-plista', 'price': 100000, 'isFeatured': True, 'heroimagealttag': '', 'description': "It is a long established fact that a reader will be distracted by the readable content of a page when looking at its layout. The point of using Lorem Ipsum is that it has a more-or-less normal distribution of letters, as opposed to using 'Content here, content here',", 'year': '2010', 'kilometers': '24000', 'transmission': 'Automatic', 'exteriorcolor': 'puple', 'warranty': 'Available', 'interiorcolor': 'Purple + Black', 'horsepower': '240hp', 'enginesize': '6.6L V12', 'specs': 'GCC', 'vin': 'ZHWUR1ZF7GLA05500', 'forBidding': True, 'heroCarImage': 'https://eurotechtrading.s3.ap-south-1.amazonaws.com/images/trip/img-15.jpg', 'carImages': ['https://eurotechtrading.s3.ap-south-1.amazonaws.com/images/cars/related_0_img-1.png', 'https://eurotechtrading.s3.ap-south-1.amazonaws.com/images/cars/r
# ...

# %%
import gpt
a =gpt.userQuestion("hy")
# Out:
# content='1' response_metadata={'token_usage': {'completion_time': 0.003, 'completion_tokens': 1, 'prompt_time': 0.035, 'prompt_tokens': 107, 'queue_time': None, 'total_time': 0.038000000000000006, 'total_tokens': 108}, 'model_name': 'llama3-70b-8192', 'system_fingerprint': 'fp_c1a4bcec29', 'finish_reason': 'stop', 'logprobs': None} id='run-26236215-5ce3-45e9-a600-b2ecf67d3a4c-0' 0,1
# Conversation without dataframe.
# second time

# %%
a["response"]
# Out:
# 'Hi again! I think we got a little stuck. Would you like to ask a question about one of the alternative models I mentioned earlier, or maybe explore other options in the $60,000 price range?'

# %%
a =gpt.userQuestion("which one is the cheepest car")
# Out:
# content='1' response_metadata={'token_usage': {'completion_time': 0.003, 'completion_tokens': 1, 'prompt_time': 0.038, 'prompt_tokens': 114, 'queue_time': None, 'total_time': 0.041, 'total_tokens': 115}, 'model_name': 'llama3-70b-8192', 'system_fingerprint': 'fp_75920cad0c', 'finish_reason': 'stop', 'logprobs': None} id='run-215439a7-9264-416c-88ba-027d25f58259-0' 0,1
# Conversation without dataframe.
# second time

# %%
a
# Out:
# {'input': 'which one is the cheepest car',
# ...

# %%
a =gpt.userQuestion("actually i have very less buget like 60k is there any model here for me")
# Out:
# content='1' response_metadata={'token_usage': {'completion_time': 0.003, 'completion_tokens': 1, 'prompt_time': 0.041, 'prompt_tokens': 124, 'queue_time': None, 'total_time': 0.044000000000000004, 'total_tokens': 125}, 'model_name': 'llama3-70b-8192', 'system_fingerprint': 'fp_75920cad0c', 'finish_reason': 'stop', 'logprobs': None} id='run-49f10d91-341d-451b-8412-c4c21e3698be-0' 0,1
# Conversation without dataframe.
# second time

# %%
a =gpt.userQuestion("yes i would like to see alternatives")
# Out:
# content='1' response_metadata={'token_usage': {'completion_time': 0.003, 'completion_tokens': 1, 'prompt_time': 0.036, 'prompt_tokens': 113, 'queue_time': None, 'total_time': 0.039, 'total_tokens': 114}, 'model_name': 'llama3-70b-8192', 'system_fingerprint': 'fp_9625f32860', 'finish_reason': 'stop', 'logprobs': None} id='run-9e8db205-e9f8-4c76-b8d4-2195efdcfded-0' 0,1
# Conversation without dataframe.
# second time

# %%
a["response"]
# Out:
# 'Here are some alternatives to Ferrari in the $60,000 price range: \n\n* Porsche 718 Cayman: A sleek, high-performance roadster with a 3.0L turbo engine, starting at around $56,000.\n* Audi TT RS: A stylish, all-wheel-drive coupe with a 2.5L turbo engine, starting at around $64,000.\n* Mercedes-AMG SLC 43: A powerful, compact roadster with a 3.0L V6 engine, starting at around $62,000.\n* BMW Z4 M40i: A high-performance roadster with a 3.0L turbo engine, starting at around $63,000.\n\nWould you like me to provide more details on any of these models?'

# %%
# Out:
# {'result': {'data': {'json': [{'id': '65cdc4b6c80de2014a79b41c', 'name': 'Ferrari 488 Pista', 'slug': 'ferrari-488-plista', 'price': 100000, 'isFeatured': True, 'heroimagealttag': '', 'description': "It is a long established fact that a reader will be distracted by the readable content of a page when looking at its layout. The point of using Lorem Ipsum is that it has a more-or-less normal distribution of letters, as opposed to using 'Content here, content here',", 'year': '2010', 'kilometers': '24000', 'transmission': 'Automatic', 'exteriorcolor': 'puple', 'warranty': 'Available', 'interiorcolor': 'Purple + Black', 'horsepower': '240hp', 'enginesize': '6.6L V12', 'specs': 'GCC', 'vin': 'ZHWUR1ZF7GLA05500', 'forBidding': True, 'heroCarImage': 'https://eurotechtrading.s3.ap-south-1.amazonaws.com/images/trip/img-15.jpg', 'carImages': ['https://eurotechtrading.s3.ap-south-1.amazonaws.com/images/cars/related_0_img-1.png', 'https://eurotechtrading.s3.ap-south-1.amazonaws.com/images/cars/r
# ...

# %%
import gpt
b = gpt.userQuestion("do you have farrari")
# Out:
# content='1' response_metadata={'token_usage': {'completion_time': 0.003, 'completion_tokens': 1, 'prompt_time': 0.207, 'prompt_tokens': 147, 'queue_time': None, 'total_time': 0.21, 'total_tokens': 148}, 'model_name': 'llama3-70b-8192', 'system_fingerprint': 'fp_75920cad0c', 'finish_reason': 'stop', 'logprobs': None} id='run-c3c0638e-efe9-4abc-8db2-4df9ba8849fa-0' 0,1
# taking from database
# database_---call
# [('Ferrari 488 Pista',), ('Ferrari 458',), ('Ferrari 458 Spider ',), ('2021 Ferrari F8 Tributo Base',), ('2023 Ferrari 812 GTS Base',)] answerfromQuery
# [('Ferrari 488 Pista',), ('Ferrari 458',), ('Ferrari 458 Spider ',), ('2021 Ferrari F8 Tributo Base',), ('2023 Ferrari 812 GTS Base',)] this is from datafr

# %%
b
# Out:
# "[('Ferrari 488 Pista',), ('Ferrari 458',), ('Ferrari 458 Spider ',), ('2021 Ferrari F8 Tributo Base',), ('2023 Ferrari 812 GTS Base',)]"
